# %%
# %config InlineBackend.figure_formats=['svg']
from os import listdir
from matplotlib import pyplot as plt, ticker as mticker
import numpy as np

# %%
config = {'MAX 1D_.npy' : {'Name' : 'Max', 'color' : '#6D7680', 'line' : 'dashed', 'shift_y' : [0,0,0], 'n_photons' : [0,12]},
          'AREA 1D_.npy' : {'Name' : 'Area', 'color' : '#6D7680', 'line' : 'dashed', 'shift_y' : [0,-0.005,0], 'n_photons' : [1,21]},

          'PCA 1D_.npy' : {'Name' : 'PCA 1D', 'color' : '#6D7680', 'line' : '-', 'shift_y' : [-0.008,-0.002,0], 'n_photons' : [0,20]},
          'PCA 2D_.npy' : {'Name' : 'PCA 2D', 'color' : '#6D7680', 'line' : 'dashed', 'shift_y' : [0,0,0], 'n_photons' : [0,23]},

        
          #'KPCA Pol 1D_.npy' : {'Name' : 'PCA 1D', 'color' : '#6D7680', 'line' : '-', 'shift_y' : [0,0,0], 'n_photons' : [0,-1]},
          #'KPCA RBF 1D_.npy' : {'Name' : 'PCA 1D', 'color' : '#6D7680', 'line' : '-', 'shift_y' : [0,0,0], 'n_photons' : [0,-1]},
          #'KPCA Sig 1D_.npy' : {'Name' : 'PCA 1D', 'color' : '#6D7680', 'line' : '-', 'shift_y' : [0,0,0], 'n_photons' : [0,-1]},
          #'KPCA Cos 1D_.npy' : {'Name' : 'PCA 1D', 'color' : '#6D7680', 'line' : '-', 'shift_y' : [0,0,0], 'n_photons' : [0,-1]},

          #'KPCA Pol 2D_.npy' : {'Name' : 'PCA Pol. 2D', 'color' : '#6D7680', 'line' : '-', 'shift_y' : [0,0,0], 'n_photons' : [0,23]},
          'KPCA RBF 2D_.npy' : {'Name' : 'PCA RBF 2D', 'color' : '#6D7680', 'line' : 'dotted', 'shift_y' : [0,-0.015,0], 'n_photons' : [0,18]},
          'KPCA Sig 2D_.npy' : {'Name' : 'PCA Sig. 2D', 'color' : '#6D7680', 'line' : 'dashed', 'shift_y' : [0,-0.023,0], 'n_photons' : [0,17]},
          'KPCA Cos 2D_.npy' : {'Name' : 'PCA Cos. 2D', 'color' : '#6D7680', 'line' : '-', 'shift_y' : [0,0,0], 'n_photons' : [0,7]},
        
          'ISO 1D_.npy' : {'Name' : 'Isomap', 'color' : '#6D7680', 'line' : (0, (1, 1)), 'shift_y' : [-0.025,-0.0015,0], 'n_photons' : [0,23]},
          'tSNE 1D_.npy' : {'Name' : 't-SNE 1D', 'color' : '#E0607E', 'line' : '-', 'shift_y' : [0,0.005,0], 'n_photons' : [0,22]},
          'tSNE 2D_.npy' : {'Name' : 't-SNE 2D', 'color' : '#E0607E', 'line' : '-', 'shift_y' : [0,0.007,0], 'n_photons' : [0,23]},
          #'AUTO_.npy' : {'Name' : 'Autoencoder', 'color' : '#E0607E', 'shift_y' : [0,0,0], 'n_photons' : [0,-1]},
          'PTSNE 1D_.npy' : {'Name' : 'Autoencoder 1D', 'color' : '#79AEA3', 'line' : '-', 'shift_y' : [-0.0,-0.007,0], 'n_photons' : [0,21]},
          'PTSNE 2D_.npy' : {'Name' : 'Autoencoder 2D', 'color' : '#79AEA3', 'line' : '-', 'shift_y' : [-0.02,0.005,0], 'n_photons' : [0,21]},
        }

pad = 0.4
path_results = r'src/Results TES (Uniform)/'
xlim_ = [[0.66,1.01], [0.92,1.01], [0.8,1.01]]
min_considered = [0.5, 0.5, 0.5]
yscale_ = ['log', ]

methods = ['Max', 'Area', 'PCA', #'K-PCA (Polynomial)',
           #'K-PCA (RBF)', 'K-PCA (Sigmoid)',
           'K-PCA (Cosine)', 'NMF', 't-SNE', 'Isomap',
           'Autoencoder', 'Autoencoder\nFiltered']

colors = ["#81C14B", "#81C14B", "#6D7680", "#6D7680", "#6D7680", "#6D7680" , 
          "#6D7680", "#6D7680", "#E0607E", "#E0607E", "#79AEA3", "#79AEA3", "#79AEA3"]
metrics = ['Confidence', 'Trustworthiness Euclidian', 'Trustworthiness Cosine']

# %%
for index_metric, metric in enumerate(metrics):
    
    with plt.style.context("seaborn-v0_8"):
        plt.figure(figsize = (6,4))

        for index_method, method in enumerate(config):

                method_dict = config[method]
                result = np.load(f'{path_results}{metric}/{method}')
                print(method)
                
                i, f = method_dict['n_photons']
                sc = result[i:f]
                photon = np.arange(i,f,1)
                condition = sc >= min_considered[index_metric]
                sc = sc[condition]
                photon = photon[condition]
                y_start = sc[-1]
                y_end = sc[-1] + method_dict['shift_y'][index_metric]
                x_start = photon[-1]#len(sc)-1
                x_end = photon[-1]+1#len(sc)+1
                
                plt.plot(photon, sc, c = method_dict['color'], alpha=0.6, linestyle = method_dict['line'])
                plt.plot([x_start, (x_start + x_end - pad) / 2 , x_end - pad], 
                        [y_start, y_end, y_end], 
                        color = method_dict['color'], 
                        alpha=0.5, 
                        ls="dashed")
                plt.text(x_end, 
                        y_end, 
                        method_dict['Name'], 
                        color = method_dict['color'], 
                        fontsize=12, 
                        weight="bold", 
                        va = "center")
        plt.ylabel(metric)
        plt.xlim(0,28)
        plt.ylim(xlim_[index_metric])
        #plt.yscale('log')
        plt.xlabel('Photon number')
        plt.show()
# Out:
# MAX 1D_.npy
# AREA 1D_.npy
# PCA 1D_.npy
# PCA 2D_.npy
# KPCA RBF 2D_.npy
# KPCA Sig 2D_.npy
# KPCA Cos 2D_.npy
# ISO 1D_.npy
# tSNE 1D_.npy
# tSNE 2D_.npy
# PTSNE 1D_.npy
# PTSNE 2D_.npy
# MAX 1D_.npy
# AREA 1D_.npy
# PCA 1D_.npy
# PCA 2D_.npy
# KPCA RBF 2D_.npy
# KPCA Sig 2D_.npy
# KPCA Cos 2D_.npy
# ISO 1D_.npy
# tSNE 1D_.npy
# tSNE 2D_.npy
# PTSNE 1D_.npy
# PTSNE 2D_.npy
# MAX 1D_.npy
# AREA 1D_.npy
# PCA 1D_.npy
# PCA 2D_.npy
# KPCA RBF 2D_.npy
# KPCA Sig 2D_.npy
# KPCA Cos 2D_.npy
# ISO 1D_.npy
# tSNE 1D_.npy
# tSNE 2D_.npy
# PTSNE 1D_.npy
# PTSNE 2D_.npy

# %%
metric = 'Trustworthiness Euclidian'
index_metric = 1
trust = []
name_method = []


for index_method, method in enumerate(config):

        method_dict = config[method]
        result = np.load(f'{path_results}{metric}/{method}')
        print(method)
        trust.append(result[-1])
        name_method.append(method_dict['Name'])

y_pos = np.arange(len(trust))
    
with plt.style.context("seaborn-v0_8"):
    plt.figure(figsize = (6,3))
    ax = plt.gca()
    hbars = ax.barh(y_pos, trust, align='center')
    ax.set_yticks(y_pos, labels=name_method)
    #plt.ylabel(metric)
    ax.bar_label(hbars, fmt='%.3f', padding=3)
    ax.set_xscale('log')
    ax.xaxis.set_minor_formatter(mticker.ScalarFormatter())
    ax.set_xlabel(metric)
    ax.set_xlim([0.95,0.99999])
    plt.show()
# Out:
# MAX 1D_.npy
# AREA 1D_.npy
# PCA 1D_.npy
# PCA 2D_.npy
# KPCA RBF 2D_.npy
# KPCA Sig 2D_.npy
# KPCA Cos 2D_.npy
# ISO 1D_.npy
# tSNE 1D_.npy
# tSNE 2D_.npy
# PTSNE 1D_.npy
# PTSNE 2D_.npy
