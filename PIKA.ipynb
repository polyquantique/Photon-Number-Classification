# %%
from ExistingAlgorithms.PIKA import PIKA

# %%
config = {
    'Dataset_path'          : "Datasets/Oxford",#Oxford",#NIST (250)",#NIST PIKA (4096)",#NIST (250)",
    'Dataset_signal_size'   : 496,#496,#250,#4096,#250,
    'Average_photon_number' : 3,
    'Epochs'                : 20,
    'Optimization_iter'     : 20
}

# %%
alg = PIKA(config)
O_k = alg.run_PIKA(plot=True)
# Out:
# Epoch:   0%|          | 0/20 [00:00<?, ?it/s]
