# %%
from ExistingAlgorithms.PIKA import PIKA

# %%
config = {
    'Dataset_path'          : "Datasets/NIST PIKA 1 (4096)",#Oxford",#NIST (250)",#NIST PIKA (4096)",#NIST (250)",
    'Dataset_signal_size'   : 4096,#496,#250,#4096,#250,
    'Average_photon_number' : 1.49,
    'Epochs'                : 100,
    'Optimization_iter'     : 20
}

# %%
alg = PIKA(config)
O_k = alg.run_PIKA(plot=True)
# Out:
# Epoch:   0%|          | 0/100 [00:00<?, ?it/s]
